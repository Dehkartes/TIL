# %% [markdown]
# <a href="https://colab.research.google.com/github/hanghae-plus-AI/AI-1-jhtwiz/blob/main/4%EC%A3%BC%EC%B0%A8_%EA%B8%B0%EB%B3%B8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HuggingFace로 뉴스 기사 분류하기

# %%
# !pip install transformers datasets evaluate accelerate scikit-learn
# Out:
# Requirement already satisfied: transformers in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (4.45.2)
# Requirement already satisfied: datasets in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (2.19.1)
# Requirement already satisfied: evaluate in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (0.4.0)
# Requirement already satisfied: accelerate in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (1.0.0)
# Requirement already satisfied: scikit-learn in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (1.5.1)
# Requirement already satisfied: filelock in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: responses<0.19 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from evaluate) (0.13.3)
# Requirement already satisfied: psutil in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: six in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from responses<0.19->evaluate) (1.16.0)
# Requirement already satisfied: sympy in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from torch>=1.10.0->accelerate) (1.13.2)
# Requirement already satisfied: networkx in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: colorama in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sejin\.conda\envs\ai_standard\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import random
import evaluate
import numpy as np

from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
db = load_dataset("fancyzhx/ag_news")
db
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 120000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 7600
#     })
# })

# %%
db['train'][0]
# Out:
# {'text': "Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\\band of ultra-cynics, are seeing green again.",
#  'label': 2}

# %%
db['train'].features['label'].names
# Out:
# ['World', 'Sports', 'Business', 'Sci/Tech']

# %%
len_classes = len(db['train'].features['label'].names)
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def preprocess_function(data):
    return tokenizer(data["text"])

db_tokenized = db.map(preprocess_function, batched=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# c:\Users\Sejin\.conda\envs\AI_Standard\lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Sejin\.cache\huggingface\hub\models--bert-base-cased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Map:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7600 [00:00<?, ? examples/s]

# %%
db_tokenized['train'][0].keys()
# Out:
# dict_keys(['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'])

# %%
db_split = db_tokenized['train'].train_test_split(test_size=0.2)
db_train, db_val = db_split['train'], db_split['test']
db_test = db_tokenized['test']

# %%
len(db_train), len(db_val), len(db_test)
# Out:
# (96000, 24000, 7600)

# %%
from transformers import BertConfig

config = BertConfig()

config.hidden_size = 128  # BERT layer의 기본 hidden dimension
config.intermediate_size = 256  # FFN layer의 중간 hidden dimension
config.num_hidden_layers = 5  # BERT layer의 개수
config.num_attention_heads = 4  # Multi-head attention에서 사용하는 head 개수
config.num_labels = len_classes  # 마지막에 예측해야 하는 분류 문제의 class 개수

model = AutoModelForSequenceClassification.from_config(config)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir='hf_transformer',  # 모델, log 등을 저장할 directory
    num_train_epochs=10,  # epoch 수
    per_device_train_batch_size=64,  # training data의 batch size
    per_device_eval_batch_size=64,  # validation data의 batch size
    logging_strategy="epoch",  # Epoch가 끝날 때마다 training loss 등을 log하라는 의미
    do_train=True,  # 학습을 진행하겠다는 의미
    do_eval=True,  # 학습 중간에 validation data에 대한 평가를 수행하겠다는 의미
    eval_strategy="epoch",  # 매 epoch가 끝날 때마다 validation data에 대한 평가를 수행한다는 의미
    save_strategy="epoch",  # 매 epoch가 끝날 때마다 모델을 저장하겠다는 의미
    learning_rate=1e-3,  # optimizer에 사용할 learning rate
    load_best_model_at_end=True  # 학습이 끝난 후, validation data에 대한 성능이 가장 좋은 모델을 채택하겠다는 의미
)

# %%
import evaluate

accuracy = evaluate.load("accuracy")


def compute_metrics(pred):
    predictions, labels = pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
from transformers import EarlyStoppingCallback


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=db_train,
    eval_dataset=db_val,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=3)]
)

# %%
trainer.train()
# Out:
#   0%|          | 0/15000 [00:00<?, ?it/s]
# {'loss': 1.3869, 'grad_norm': 0.18240629136562347, 'learning_rate': 0.0009000000000000001, 'epoch': 1.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.386410117149353, 'eval_accuracy': 0.252125, 'eval_runtime': 6.4637, 'eval_samples_per_second': 3713.029, 'eval_steps_per_second': 58.016, 'epoch': 1.0}
# {'loss': 1.3865, 'grad_norm': 0.08970958739519119, 'learning_rate': 0.0008, 'epoch': 2.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.3866215944290161, 'eval_accuracy': 0.250125, 'eval_runtime': 6.3834, 'eval_samples_per_second': 3759.766, 'eval_steps_per_second': 58.746, 'epoch': 2.0}
# {'loss': 1.3865, 'grad_norm': 0.1003548726439476, 'learning_rate': 0.0007, 'epoch': 3.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.386256456375122, 'eval_accuracy': 0.252125, 'eval_runtime': 6.4448, 'eval_samples_per_second': 3723.91, 'eval_steps_per_second': 58.186, 'epoch': 3.0}
# {'loss': 1.3865, 'grad_norm': 0.10675675421953201, 'learning_rate': 0.0006, 'epoch': 4.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.3863070011138916, 'eval_accuracy': 0.24495833333333333, 'eval_runtime': 6.4814, 'eval_samples_per_second': 3702.905, 'eval_steps_per_second': 57.858, 'epoch': 4.0}
# {'loss': 1.3865, 'grad_norm': 0.11762792617082596, 'learning_rate': 0.0005, 'epoch': 5.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.3862969875335693, 'eval_accuracy': 0.252125, 'eval_runtime': 6.4881, 'eval_samples_per_second': 3699.099, 'eval_steps_per_second': 57.798, 'epoch': 5.0}
# {'loss': 1.3864, 'grad_norm': 0.11160490661859512, 'learning_rate': 0.0004, 'epoch': 6.0}
#   0%|          | 0/375 [00:00<?, ?it/s]
# {'eval_loss': 1.386339545249939, 'eval_accuracy': 0.24495833333333333, 'eval_runtime': 6.5057, 'eval_samples_per_second': 3689.08, 'eval_steps_per_second': 57.642, 'epoch': 6.0}
# {'train_runtime': 334.2082, 'train_samples_per_second': 2872.461, 'train_steps_per_second': 44.882, 'train_loss': 1.386553955078125, 'epoch': 6.0}
# TrainOutput(global_step=9000, training_loss=1.386553955078125, metrics={'train_runtime': 334.2082, 'train_samples_per_second': 2872.461, 'train_steps_per_second': 44.882, 'total_flos': 354945644224512.0, 'train_loss': 1.386553955078125, 'epoch': 6.0})

# %%
#결과 데이터 확인해보기
trainer.state.log_history
# Out:
# [{'loss': 1.3282,
#   'grad_norm': 0.5434260368347168,
#   'learning_rate': 0.0009000000000000001,
#   'epoch': 1.0,
#   'step': 1500},
#  {'eval_loss': 1.3871588706970215,
#   'eval_accuracy': 0.252125,
#   'eval_runtime': 6.2861,
#   'eval_samples_per_second': 3817.935,
#   'eval_steps_per_second': 59.655,
#   'epoch': 1.0,
#   'step': 1500},
#  {'loss': 1.387,
#   'grad_norm': 0.15216679871082306,
#   'learning_rate': 0.0008,
#   'epoch': 2.0,
#   'step': 3000},
#  {'eval_loss': 1.3871299028396606,
#   'eval_accuracy': 0.24495833333333333,
#   'eval_runtime': 6.4908,
#   'eval_samples_per_second': 3697.542,
#   'eval_steps_per_second': 57.774,
#   'epoch': 2.0,
#   'step': 3000},
#  {'loss': 1.3866,
#   'grad_norm': 0.12614478170871735,
#   'learning_rate': 0.0007,
#   'epoch': 3.0,
#   'step': 4500},
#  {'eval_loss': 1.3862649202346802,
#   'eval_accuracy': 0.250125,
#   'eval_runtime': 6.3027,
#   'eval_samples_per_second': 3807.903,
#   'eval_steps_per_second': 59.498,
#   'epoch': 3.0,
#   'step': 4500},
#  {'loss': 1.3865,
#   'grad_norm': 0.11442901194095612,
#   'learning_rate': 0.0006,
#   'epoch': 4.0,
#   'step': 6000},
#  {'eval_loss': 1.3862847089767456,
#   'eval_accuracy': 0.252125,
#   'eval_runtime': 6.4215,
#   'eval_samples_per_second': 3737.433,
#   'eval_steps_per_second': 58.397,
#   'epoch': 4.0,
#   'step': 6000},
#  {'loss': 1.3865,
#   'grad_norm': 0.13152740895748138,
#   'learning_rate': 0.0005,
#   'epoch': 5.0,
#   'step': 7500},
#  {'eval_loss': 1.3863849639892578,
#   'eval_accuracy': 0.252125,
#   'eval_runtime': 6.3227,
#   'eval_samples_per_second': 3795.825,
#   'eval_steps_per_second': 59.31,
#   'epoch': 5.0,
#   'step': 7500},
#  {'loss': 1.3864,
#   'grad_norm': 0.14333727955818176,
#   'learning_rate': 0.0004,
#   'epoch': 6.0,
#   'step': 9000},
#  {'eval_loss': 1.386322259902954,
#   'eval_accuracy': 0.24495833333333333,
#   'eval_runtime': 6.3878,
#   'eval_samples_per_second': 3757.186,
#   'eval_steps_per_second': 58.706,
#   'epoch': 6.0,
#   'step': 9000},
#  {'train_runtime': 327.6435,
#   'train_samples_per_second': 2930.014,
#   'train_steps_per_second': 45.781,
#   'total_flos': 354945644224512.0,
#   'train_loss': 1.376881551106771,
#   'epoch': 6.0,
#   'step': 9000}]

# %%
import matplotlib.pyplot as plt

train_logs = trainer.state.log_history
train_acc = [log["eval_accuracy"] for log in train_logs if "eval_accuracy" in log]

plt.plot(train_acc)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 train_logs = trainer.state.log_history
#       4 train_acc = [log["eval_accuracy"] for log in train_logs if "eval_accuracy" in log]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#테스트 데이터로 정확도 평가
trainer.evaluate(db_test)
# Out:
#     <div>
#
#       <progress value='119' max='119' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [119/119 00:06]
#     </div>
# {'eval_loss': 0.2757314443588257,
#  'eval_accuracy': 0.9130263157894737,
#  'eval_runtime': 6.9431,
#  'eval_samples_per_second': 1094.605,
#  'eval_steps_per_second': 17.139,
#  'epoch': 6.0}

# %%
trainer.save_model()

# %%
from transformers import pipeline

#주어진 예시로 예측 결과 출력
classifier = pipeline("sentiment-analysis", model="./hf_transformer/", device='cuda')
test_text = "UK charges 8 in terror plot linked to alert in US LONDON, AUGUST 17: Britain charged eight terror suspects on Tuesday with conspiracy to commit murder and said one had plans that could be used in striking US buildings that were the focus of security scares this month."
print(classifier(test_text))
# Out:
# [{'label': 'LABEL_0', 'score': 0.9822717905044556}]
